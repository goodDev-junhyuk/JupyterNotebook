# %% [markdown]
# <a href="https://colab.research.google.com/github/goodDev-junhyuk/JupyterNotebook/blob/main/Matplotlib_Pie_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01. Matplotlib_Pie_Chart.

# %%
# Pie_Chart는 범주별 구성 비율을 원형으로 나타내는 그래프
# pie() 함수 이용

import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0, 0.10, 0, 0.10]
colors = ['silver', 'gold', '#8fd9b6', '#d395d0']

# 중심에서 벗어나는 정도 설정 explode 이용, shadow를 이용하여 그림자 표현
# colors로 다양한 색상 지정, Hex Code로도 지정 가능.
plt.pie(ratio, labels=labels, autopct='%.1f%%', 
        startangle=260, counterclock=False, 
        explode=explode, shadow=True, colors=colors)
plt.show()

# %% [markdown]
# # 02. Matplotlib 히트맵

# %%
import matplotlib.pyplot as plt
import numpy as np

arr = np.random.standard_normal((30, 40))

# matshow() 함수 이용.
plt.matshow(arr)
# 컬러바 추가
plt.colorbar()
plt.show()

# %%
# 컬러맵 지정
import matplotlib.pyplot as plt
import numpy as np

arr = np.random.standard_normal((30, 40))
cmap = plt.get_cmap('PiYG')
#cmap = plt.get_cmap('BuGn')
#cmap = plt.get_cmap('Greys')
#cmap = plt.get_cmap('bwr')

plt.matshow(arr, cmap=cmap)

plt.colorbar()
plt.show()

# %% [markdown]
# # 03. 여러 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 04. Matplotlib 컬러맵 설정

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)
arr = np.random.standard_normal((8, 100))

# subplot 함수를 사용하여 네 영역에 각각의 그래프 표현.

plt.subplot(2, 2, 1)
#plt.scatter(arr[0], arr[1], c=arr[1], cmap = 'spring')
plt.scatter(arr[0], arr[1], c=arr[1])
plt.spring()
plt.title('spring')
plt.colorbar()

plt.subplot(2, 2, 2)
plt.scatter(arr[2], arr[3], c=arr[3])
plt.summer()
plt.title('summer')
plt.colorbar()

plt.subplot(2, 2, 3)
plt.scatter(arr[4], arr[5], c=arr[5])
plt.autumn()
plt.title('autumn')
plt.colorbar()

plt.subplot(2, 2, 4)
plt.scatter(arr[6], arr[7], c=arr[7])
plt.winter()
plt.title('winter')
plt.colorbar()

plt.tight_layout()
plt.show()
